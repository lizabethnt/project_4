# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# File to Load
global_footprint_data = Path("/Users/lizmartin-strong/project_4/data/Global Ecological Footprint 2023.csv")

# Read data file and store into Pandas DataFrames
global_df = pd.read_csv(global_footprint_data, encoding="ISO-8859-1")
global_df.head()
# Out:
#                Country                     Region  SDGi Life Exectancy   HDI  \
# 0          Afghanistan   Middle East/Central Asia  52.5             62  0.48
# 1              Albania               Other Europe  71.6             76   0.8
# 2              Algeria                     Africa  71.5             76  0.75
# 3               Angola                     Africa  50.9             62  0.59
# 4  Antigua and Barbuda  Central America/Caribbean   NaN             78  0.79
#
#   Per Capita GDP Income Group Population (millions)  Cropland Footprint  \
# 0            NaN           LI                  40.8                 0.4
# 1       $14,889            UM                   2.9                 0.8
# 2       $11,137            UM                  45.4                 0.7
# 3        $6,304            LM                    35                 0.2
# 4       $18,749            HI                   0.1                 NaN
#
# ...

# %%
# Generate summary statistics
global_df.describe()
# Out:
#        Cropland Footprint  Grazing Footprint  Forest Product Footprint  \
# count          152.000000         152.000000                152.000000
# mean             0.582895           0.270395                  0.428289
# std              0.345218           0.431513                  0.565968
# min              0.100000           0.000000                  0.000000
# 25%              0.300000           0.100000                  0.200000
# 50%              0.500000           0.200000                  0.200000
# 75%              0.800000           0.300000                  0.500000
# max              1.900000           4.700000                  4.300000
#
#        Carbon Footprint  Fish Footprint  Built up land  \
# count        152.000000      152.000000     152.000000
# mean           1.533553        0.146053       0.084211
# std            1.771703        0.434274       0.093572
# min            0.000000        0.000000       0.000000
# ...

# %%
# Plot your data to see what's in your DataFrame
global_df.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
global_df.columns
# Out:
# Index(['Country', 'Region', 'SDGi', 'Life Exectancy', 'HDI', 'Per Capita GDP',
#        'Income Group', 'Population (millions)', 'Cropland Footprint',
#        'Grazing Footprint', 'Forest Product Footprint', 'Carbon Footprint',
#        'Fish Footprint', 'Built up land',
#        'Total Ecological Footprint (Consumption)', 'Cropland', 'Grazing land',
#        'Forest land', 'Fishing ground', 'Built up land.1',
#        'Total biocapacity ', 'Ecological (Deficit) or Reserve',
#        'Number of Earths required', 'Number of Countries required'],
#       dtype='object')

# %%
print(global_df.dtypes)
# Out:
# Country                                      object
# Region                                       object
# SDGi                                         object
# Life Exectancy                               object
# HDI                                          object
# Per Capita GDP                               object
# Income Group                                 object
# Population (millions)                        object
# Cropland Footprint                          float64
# Grazing Footprint                           float64
# Forest Product Footprint                    float64
# Carbon Footprint                            float64
# Fish Footprint                              float64
# Built up land                               float64
# Total Ecological Footprint (Consumption)    float64
# Cropland                                    float64
# Grazing land                                float64
# Forest land                                 float64
# ...

# %%
global_df["Per Capita GDP"].drop('NaN',inplace=True)
global_df["Per Capita GDP"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/lizmartin-strong/project_4/liz_exploratory.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/lizmartin-strong/project_4/liz_exploratory.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> global_df["Per Capita GDP"].drop('NaN',inplace=True)
#       <a href='vscode-notebook-cell:/Users/lizmartin-strong/project_4/liz_exploratory.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> global_df["Per Capita GDP"]
#
# File ~/Library/Python/3.12/lib/python/site-packages/pandas/core/series.py:5356, in Series.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5259 def drop(
#    5260     self,
#    5261     labels: IndexLabel | None = None,
#    (...)
#    5268     errors: IgnoreRaise = "raise",
#    5269 ) -> Series | None:
#    5270     """
#    5271     Return Series with specified index labels removed.
#    5272
#    (...)
# ...

# %%
#From Stackoverflow (https://stackoverflow.com/questions/76447673/convert-a-column-of-currency-strings-into-floats)
df['invoice_value2']=df['invoice_value2'].replace('[\$,]','', regex=True).astype(float)

# %%
# Remove commas from the 'Population (millions)' column using a for loop
for index, value in enumerate(global_df['Population (millions)']):
    global_df.at[index, 'Population (millions)'] = value.replace(",", "")
print(global_df['Population (millions)'])
# Out:
# 0      40.8
# 1       2.9
# 2      45.4
# 3        35
# 4       0.1
#        ...
# 177    29.3
# 178      99
# 179    31.2
# 180    19.5
# 181    15.3
# Name: Population (millions), Length: 182, dtype: object

# %%
# Remove commas from the 'Per Capita GDP' column using a for loop
for value in global_df['Per Capita GDP']:
    global_df.at['Per Capita GDP'] = value.replace("$", "")
    global_df.at['Per Capita GDP'] = value.replace(",", "")    
print(global_df['Per Capita GDP'])

# for index, value in enumerate(global_df['Per Capita GDP']):
#     if value.dtype()=='float64':
#         print("already float")
#     else:
#         global_df.at[index, 'Per Capita GDP'] = value.replace("$", "")
#         global_df.at[index, 'Per Capita GDP'] = value.replace(",", "")    
# print(global_df['Per Capita GDP'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/lizmartin-strong/project_4/liz_exploratory.ipynb Cell 9 line 3
#       <a href='vscode-notebook-cell:/Users/lizmartin-strong/project_4/liz_exploratory.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> # Remove commas from the 'Per Capita GDP' column using a for loop
#       <a href='vscode-notebook-cell:/Users/lizmartin-strong/project_4/liz_exploratory.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> for value in global_df['Per Capita GDP']:
# ----> <a href='vscode-notebook-cell:/Users/lizmartin-strong/project_4/liz_exploratory.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a>     global_df.at['Per Capita GDP'] = value.replace("$", "")
#       <a href='vscode-notebook-cell:/Users/lizmartin-strong/project_4/liz_exploratory.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a>     global_df.at['Per Capita GDP'] = value.replace(",", "")
# ...

# %%
global_df['Population (millions)'] = global_df['Population (millions)'].astype('float64')
# global_df['Grazing Footprint'] = global_df['Grazing Footprint'].astype('int64'),
# global_df['Forest Product Footprint'] = global_df['Forest Product Footprint'].astype('int64'),
#global_df['Carbon Footprint'] = global_df['Carbon Footprint'].astype('object'),
# global_df['Fish Footprint'] = global_df['Fish Footprint'].astype('object'),
# global_df['Built up land'] = global_df['Built up land'].astype('object'),
# global_df['Forest Product Footprint'] = global_df['Forest Product Footprint'].astype('object'),
# global_df['Carbon Footprint'] = global_df['Carbon Footprint'].astype('object'),
# global_df['Fish Footprint'] = global_df['Fish Footprint'].astype('object'),
# global_df['Built up land'] = global_df['Built up land'].astype('object'),
# global_df['Total Ecological Footprint (Consumption)'] = global_df['Total Ecological Footprint (Consumption)'].astype('object'),
# global_df['Cropland'] = global_df['Cropland'].astype('object'),
# global_df['Grazing land'] = global_df['Grazing land'].astype('object'),
# global_df['Forest land'] = global_df['Forest land'].astype('object'),
# global_df['Fishing ground'] = global_df['Fishing ground'].astype('object'),
# global_df['Built up land.1'] = global_df['Built up land.1'].astype('object'),
# global_df['Total biocapacity '] = global_df['Total biocapacity '].astype('object'),
# global_df['Ecological (Deficit) or Reserve'] = global_df['Ecological (Deficit) or Reserve'].astype('object'),
# global_df['Number of Earths required'] = global_df['Number of Earths required'].astype('object')

# %%
my_list = ['apple', 'banana', 'cherry']
e_list = enumerate(my_list)
print(list(e_list))
# Out:
# [(0, 'apple'), (1, 'banana'), (2, 'cherry')]

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
global_df_scaled = StandardScaler().fit_transform(global_df[['Region', 'SDGi', 'Life Exectancy', 'HDI', 'Per Capita GDP',
       'Income Group', 'Population (millions)', 'Cropland Footprint',
       'Grazing Footprint', 'Forest Product Footprint', 'Carbon Footprint',
       'Fish Footprint', 'Built up land',
       'Total Ecological Footprint (Consumption)', 'Cropland', 'Grazing land',
       'Forest land', 'Fishing ground', 'Built up land.1',
       'Total biocapacity ', 'Ecological (Deficit) or Reserve',
       'Number of Earths required', 'Number of Countries required']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/fs/__bdqblj65l1mfg08j7wgfwh0000gp/T/ipykernel_49398/1447850085.py in ?()
#       1 # Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
# ----> 2 global_df_scaled = StandardScaler().fit_transform(global_df[['Region', 'SDGi', 'Life Exectancy', 'HDI', 'Per Capita GDP',
#       3        'Income Group', 'Population (millions)', 'Cropland Footprint',
#       4        'Grazing Footprint', 'Forest Product Footprint', 'Carbon Footprint',
#       5        'Fish Footprint', 'Built up land',
#
# ~/Library/Python/3.12/lib/python/site-packages/sklearn/utils/_set_output.py in ?(self, X, *args, **kwargs)
#     293     @wraps(f)
#     294     def wrapped(self, X, *args, **kwargs):
# --> 295         data_to_wrap = f(self, X, *args, **kwargs)
# ...
